# %%
pip install requests

# %%
import requests

# API endpoint and parameters
base_url = "https://apis.data.go.kr/1613000/RTMSDataSvcAptTrade/getRTMSDataSvcAptTrade"
params = {
    "serviceKey": "iDsEbBq1YeWuOJeS5oxnDsz5ciDol0NWD%2ByNthbF69%2BFZz16yaxhqGLo3aA5FGyt9kcHpkUM2oZXYucwBAJjXQ%3D%3D",  # Replace with your service key
    "LAWD_CD": 11110,  # Area code (e.g., 11110 for Seoul Jongno-gu)
    "DEAL_YMD": 202407,  # Year and month in YYYYMM format
    "pageNo": '1',  # Page number
    "numOfRows": '10'  # Number of rows per page
}

response = requests.get(base_url, params=params)

# try:
#     # Send GET request to the API
#     response = requests.get(base_url, params=params)
#     response.raise_for_status()  # Raise HTTPError for bad responses (4xx and 5xx)

#     # Parse the response
#     data = response.json()  # Assuming the API returns JSON; change to `.text` if XML
#     print("Response Data:", data)

# except requests.exceptions.RequestException as e:
#     print("An error occurred:", e)

# if response.status_code == 200:
#     # XML 데이터 파싱
#     root = ET.fromstring(response.content)
#     items = root.find('body').find('items')
#     for item in items:
#         apt_name = item.find('aptNm').text  # 아파트 이름
#         deal_amount = item.find('dealAmount').text  # 거래 금액
#         build_year = item.find('buildYear').text  # 건축 연도
#         deal_year = item.find('dealYear').text  # 계약 연도
#         deal_month = item.find('dealMonth').text  # 계약 월
#         deal_day = item.find('dealDay').text  # 계약 일
#         dong = item.find('dong').text  # 동
#         print(f"{apt_name}, {deal_amount}, {build_year}, {deal_year}-{deal_month}-{deal_day}, {dong}")# else:
#     print(f"API 요청 실패: {response.status_code}, {response.text}")
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...
